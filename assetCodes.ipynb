# %%
import pdftotext

# %%
# Load your PDF
PATH="C:\\Users\\bmeie\\Documents\\Accounting\\costCenterInputs\\CalculationInputs\\"
fName = "GAAP Depreciation.pdf"
with open(PATH+fName, "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
# How many pages?
print(len(pdf))
# Out:
# 14

# %%
# Iterate over all the pages
for page in pdf:
    print(page)
# Out:
# Richardson Cooling Packages
# Comprehensive Depreciation [Depreciation]
# GAAP
# For the Period January 1, 2021 to December 31, 2021
# Asset Balances
#
# Selected Dates
#
# Asset ID
# Class: Computers
# 000029
# 000044
# 000111
# 000210
# 000212
# 000253
# 000254
# 000255
# 000264
# 000265
# 000286
# 000287
# 000288
# 000289
# 000325
# 000326
# 000328
# 000329
# 000332
# 000333
# 000334
# 000335
# 000337
# 000338
# 000352
# 000353
# 000354
# 000355
#
# Page: 1
#
# Placed in Service Disposal Date
# Date
#
# Dell Computer Hardware
# 4/25/2006
# Computer Equipment
# 1/8/2008
# Cabinets
# 1/31/2008
# Color Laser Printer
# 9/24/2009
# Fax Machine
# 10/28/2009
# Engineering PC - Sam
# 7/8/2010
# Engineering PC- Jon
# 7/8/2010
# Dave R's Workstation
# 8/18/2010
# Laptops for Carla and Tyler
# 11/17/2010
# Computer Quality - Jackie
# 11/29/2010
# Computer - Dave Richardson
# 1/5/2011
# Computer - Brian Meier
# 2/1/2011
# Computer - Joe O'Block
# 4/29/2011
# Computer - Carla Home Log-In
# ...

# %%
# Read all the text into one string
assetGAAP = "".join(pdf)

# %%
with open(PATH+'assetGAAP.txt', 'w') as f:
    f.write(assetGAAP)
